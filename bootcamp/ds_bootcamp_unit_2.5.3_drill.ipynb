# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.cross_decomposition import PLSRegression


sns.set_style('white')
# %matplotlib inline

# %%
n = 1000
p = 10
X = np.random.normal(size=n * p).reshape((n, p))
y = X[:, 0] + 2 * X[:, 1] + np.random.normal(size=n * 1) + 5

fig, ax = plt.subplots(figsize=(12, 9))
corrmat = pd.DataFrame(np.insert(X, 0, y, axis=1)).corr()
sns.heatmap(corrmat, vmax=0.8, square=True, cmap="plasma")
plt.show()

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)
Y_pred = regr.predict(X)
print("R-squared regression:", regr.score(X, y))
# Out:
# R-squared regression: 0.8214730505351134

# %%
pls1 = PLSRegression(n_components=3)
pls1.fit(X, y)
Y_PLS_pred = pls1.predict(X)
print("R-squared PSLR:", pls1.score(X, y))
# Out:
# R-squared PSLR: 0.8214729782253446

# %%
plt.scatter(Y_pred, Y_PLS_pred)
plt.title("Comparing LR and PLSR predictions")
plt.xlabel("Predicted by original 10 features")
plt.ylabel("Predicted by 3 features")
plt.show()

# %%
pls2 = PLSRegression(n_components=2)
pls2.fit(X, y)
Y_PLS_pred = pls2.predict(X)
plt.scatter(Y_pred, Y_PLS_pred)
plt.title("Comparing LR and PLSR predictions")
plt.xlabel("Predicted by original 10 features")
plt.ylabel("Predicted by 2 features")
plt.show()
print("R-squared PSLR:", pls2.score(X, y))
# Out:
# R-squared PSLR: 0.8214423410088291

# %%
pls3 = PLSRegression(n_components=1)
pls3.fit(X, y)
Y_PLS_pred = pls1.predict(X)
plt.scatter(Y_pred, Y_PLS_pred)
plt.title("Comparing LR and PLSR predictions")
plt.xlabel("Predicted by original 10 features")
plt.ylabel("Predicted by 1 features")
plt.show()
print("R-squared PSLR:", pls3.score(X, y))
# Out:
# R-squared PSLR: 0.8147216322044334

# %%
pls4 = PLSRegression(n_components=7)
pls4.fit(X, y)
Y_PLS_pred = pls4.predict(X)
plt.scatter(Y_pred, Y_PLS_pred)
plt.title("Comparing LR and PLSR predictions")
plt.xlabel("Predicted by original 10 features")
plt.ylabel("Predicted by 7 features")
plt.show()
print("R-squared PSLR:", pls4.score(X, y))
# Out:
# R-squared PSLR: 0.8214730505351134
